# %%
import numpy as np
import pandas as pd
import seaborn as sns


data0 = ( 'hole,	1st,	2nd,	3rd,	4th,	5th,	6th,	7th,	8th,	9th')
data1 =  ('PAR, 	[5,	4,	3,	4,	4,	3,	4,	5,	4]')
data2 =  ('Franklin, [5  4  3  5  4  3  4  6  3 ]')

x = data1
y = data2

df1=[5,	4,	3,	4,	4,	3,	4,	5,	4]
df2=[5,4,3,5,4,3,4,6,3]

plt.figure(figsize=(10,3))
plt.title('Franklins 1st golf game')
sns.lineplot(data=df2)
sns.scatterplot(data=df2)
sns.barplot(data=df1)
print(x)
print(y)
# Out:
# PAR, 	[5,	4,	3,	4,	4,	3,	4,	5,	4]
# Franklin, [5  4  3  5  4  3  4  6  3 ]

# %% [markdown]
# great, now my results look really outstanding and i dont have to swinct to read them. 1st game result.

# %% [markdown]
# now i could spend time going over the first 20 scores relating to game or i could collect 20 new scores to match my current skill streak.... decisions decisions...

# %%
import numpy as np
import pandas as pd
import seaborn as sns

data4 = ( 'hole,	1st,	2nd,	3rd,	4th,	5th,	6th,	7th,	8th,	9th')
data5 =  ('PAR, 	5,	4,	3,	4,	4,	3,	4,	5,	4')
data6 =  ('Franklin, 5  4  3  4  3  2  5  5  3')

x = data5
y = data6

df3=[5,	4,	3,	4,	4,	3,	4,	5,	4]
df4=[5,  4,  3,  4,  3,  2,  5,  5,  3]

print(x)
print(y)


plt.figure(figsize=(10,3))
plt.title('Franklins 2nd golf game')
plt.grid(True)
sns.lineplot(data=df4,)
sns.scatterplot(data=df4)
sns.barplot(data=df3)

print('Score 34 /-/ Par 36')
# Out:
# PAR, 	5,	4,	3,	4,	4,	3,	4,	5,	4
# Franklin, 5  4  3  4  3  2  5  5  3
# Score 34 /-/ Par 36

# %% [markdown]
# above is the 2nd game played with results.

# %%
import numpy as np
import pandas as pd
import seaborn as sns

data7 = ( 'hole,	1st,	2nd,	3rd,	4th,	5th,	6th,	7th,	8th,	9th')
data8 =  ('PAR, 	5,	4,	3,	4,	4,	3,	4,	5,	4')
data9 =  ('Franklin, 4  3  4  5  4  4  4  5  4 ')

x = data8
y = data9

df5=[5,	4,	3,	4,	4,	3,	4,	5,	4]
df6=[4,  3,  4,  5,  4,  4,  4,  5,  4 ]

print(x)
print(y)

plt.figure(figsize=(10,3))
plt.title('Franklins 3rd golf game')
plt.grid(True)
sns.lineplot(data=df6,)
sns.scatterplot(data=df6)
sns.barplot(data=df5)


print('Score 37  /-/ Par 36')
# Out:
# PAR, 	5,	4,	3,	4,	4,	3,	4,	5,	4
# Franklin, 4  3  4  5  4  4  4  5  4
# Score  /-/ Par 36

# %% [markdown]
# above is the 3rd game played.

# %%
import numpy as np
import pandas as pd
import seaborn as sns

data10 = ( 'hole,	1st,	2nd,	3rd,	4th,	5th,	6th,	7th,	8th,	9th')
data11 =  ('PAR, 	5,	4,	3,	4,	4,	3,	4,	5,	4')
data12 =  ('Franklin, 5  4,  3  4  4  2  5  4  3')

x = data8
y = data9

df7=[5,	4,	3,	4,	4,	3,	4,	5,	4]
df8=[5,  4,  3,  4,  4,  2,  5,  4,  3]

print(x)
print(y)

plt.figure(figsize=(10,3))
plt.title('Franklins 4th golf game')
plt.grid(True)
sns.lineplot(data=df8)
sns.scatterplot(data=df8)
sns.barplot(data=df7)


print('Score 33  /-/ Par 36')
# Out:
# PAR, 	5,	4,	3,	4,	4,	3,	4,	5,	4
# Franklin, 4  3  4  5  4  4  4  5  4
# Score 33  /-/ Par 36

# %% [markdown]
# above franklins 4th game resuls- this one -3 on Par- i love it

# %%
import numpy as np
import pandas as pd
import seaborn as sns

data13 = ( 'hole,	1st,	2nd,	3rd,	4th,	5th,	6th,	7th,	8th,	9th')
data14 =  ('PAR, 	5,	4,	3,	4,	4,	3,	4,	5,	4')
data15 =  ('Franklin,5  4  3  3  3  3  5  7  3 ')

x = data14
y = data15

df9=[5,	4,	3,	4,	4,	3,	4,	5,	4]
df10=[ 5,  4,  3,  3,  3,  3,  5,  7,  3  ]

print(x)
print(y)

plt.figure(figsize=(10,3))
plt.title('Franklins 5th golf game')
plt.grid(True)
sns.lineplot(data=df10)
sns.scatterplot(data=df10)
sns.barplot(data=df9)


print('Score 36   /-/ Par 36')
# Out:
# PAR, 	5,	4,	3,	4,	4,	3,	4,	5,	4
# Franklin,5  4  3  3  3  3  5  7  3
# Score 36   /-/ Par 36

# %% [markdown]
# above the 5th game result-

# %%
import numpy as np
import pandas as pd
import seaborn as sns

data16 = ( 'hole,	1st,	2nd,	3rd,	4th,	5th,	6th,	7th,	8th,	9th')
data17 =  ('PAR, 	5,	4,	3,	4,	4,	3,	4,	5,	4')
data18 =  ('Franklin, 5  5  3  5  5  2  5  5  3')

x = data17
y = data18

df11=[5,	4,	3,	4,	4,	3,	4,	5,	4]
df12=[5,  5,  3,  5,  5,  2,  5,  5,  3  ]

print(x)
print(y)

plt.figure(figsize=(10,3))
plt.title('Franklins 6th golf game')
plt.grid(True)
sns.lineplot(data=df12)
sns.scatterplot(data=df12)
sns.barplot(data=df11)


print('Score 38  /-/ Par 36')
# Out:
# PAR, 	5,	4,	3,	4,	4,	3,	4,	5,	4
# Franklin, 5  5  3  5  5  2  5  5  3
# Score 38  /-/ Par 36

# %% [markdown]
# the 6th game results-
